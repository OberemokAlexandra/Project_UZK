# %%
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, Model, backend as K
import torch
from accustic import Acustic_Sample

# %%
ia=Sample(path='/content/0001.uks',modelpath='/content/drive/MyDrive/Colab Notebooks/Y-Pro/Model_2_Densenet')

# %%
ia.velocity()
